# %%
import matplotlib.pyplot as plt
import pandas as pd 
import math

# %%
actual = [0.00699799999999999728, 0.0259969999999999993, 0.30895399999999995, 1.2948029999999999, 11.454257999999999, 41.62967199999999]
estimation = [0.0576276971187326126, 0.15111577458446845, 0.62485783733427525, 1.2318049520254135, 3.8236998692154884, 8.2038607969880104]
xx = [20, 100, 500, 1000, 3000, 6000]


# data = {'L':x,
#         'Time(Actual)':actual,
#         'Time(Estimated PM)':estimation}
# df = pd.DataFrame(data)

plt.figure(figsize = (20,10))

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}
plt.rc('font', **font)

plt.title("Comparison: \"Time estimated by Performance model\" VS \"the actual time\"")
plt.xlabel('Grid Size (N)')
plt.ylabel('Time taken (seconds) ')
plt.plot(xx, actual, label = "Value of Time(Actual)")
plt.plot(xx, estimation, label = "Value of Time(Estimated by Model)")

# for x,y in zip(xx,actual):

#     label = "{:.2f}".format(y)

#     plt.annotate(label, # this is the text
#                  (x,y), # these are the coordinates to position the label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center') # horizontal alignment can be left, right or center

plt.text(3000,20,'"Value of Time(Actual)')
plt.text(3000,3,'Value of Time(Estimated by Model)')

plt.show()
